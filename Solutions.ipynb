# %% [markdown]
# # Lab | Cleaning numerical data

# %% [markdown]
# For this lab, we will be using the dataset in the Customer Analysis Business Case. This dataset can be found in files_for_lab folder.

# %% [markdown]
# ### 1. Import the necessary libraries.

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import numpy as np
import getpass
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
password = getpass.getpass()
# Out:
# ········

# %% [markdown]
# ### 2. Load the we_fn_use_c_marketing_customer_value_analysis.csv into the variable customer_df.

# %%
data = pd.read_csv(r'C:\Users\claud\lab-cleaning-numerical-data\files_for_lab\we_fn_use_c_marketing_customer_value_analysis.csv')

# %% [markdown]
# ### 3. First look at its main features (head, shape, info).

# %%
data.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4            2/3/11         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
data.shape
# Out:
# (9134, 24)

# %%
data.dtypes
# Out:
# Customer                          object
# State                             object
# Customer Lifetime Value          float64
# Response                          object
# Coverage                          object
# Education                         object
# Effective To Date                 object
# EmploymentStatus                  object
# Gender                            object
# Income                             int64
# Location Code                     object
# Marital Status                    object
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                       object
# Policy                            object
# Renew Offer Type                  object
# Sales Channel                     object
# Total Claim Amount               float64
# Vehicle Class                     object
# ...

# %%
data.describe()
# Out:
#        Customer Lifetime Value        Income  Monthly Premium Auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        Months Since Last Claim  Months Since Policy Inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %% [markdown]
# ### 4. Rename the columns so they follow the PE8 (snake case).

# %%
data.columns = [x.lower().replace(" ", "_") for x in data.columns]
data.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'response', 'coverage',
#        'education', 'effective_to_date', 'employmentstatus', 'gender',
#        'income', 'location_code', 'marital_status', 'monthly_premium_auto',
#        'months_since_last_claim', 'months_since_policy_inception',
#        'number_of_open_complaints', 'number_of_policies', 'policy_type',
#        'policy', 'renew_offer_type', 'sales_channel', 'total_claim_amount',
#        'vehicle_class', 'vehicle_size'],
#       dtype='object')

# %% [markdown]
# ### 5. Change effective to date column to datetime format.

# %%
data['effective_to_date'] = pd.to_datetime(data['effective_to_date'])
data.head()
# Out:
#   customer       state  customer_lifetime_value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   effective_to_date employmentstatus gender  income  ...  \
# 0        2011-02-24         Employed      F   56274  ...
# 1        2011-01-31       Unemployed      F       0  ...
# 2        2011-02-19         Employed      F   48767  ...
# 3        2011-01-20       Unemployed      M       0  ...
# 4        2011-02-03         Employed      M   43836  ...
#
#   months_since_policy_inception number_of_open_complaints  number_of_policies  \
# ...

# %% [markdown]
# ### 6. Check NaN values per column.

# %%
data.isna().sum()
# Out:
# customer                         0
# state                            0
# customer_lifetime_value          0
# response                         0
# coverage                         0
# education                        0
# effective_to_date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location_code                    0
# marital_status                   0
# monthly_premium_auto             0
# months_since_last_claim          0
# months_since_policy_inception    0
# number_of_open_complaints        0
# number_of_policies               0
# policy_type                      0
# policy                           0
# renew_offer_type                 0
# sales_channel                    0
# total_claim_amount               0
# vehicle_class                    0
# vehicle_size                     0
# dtype: int64

# %% [markdown]
# ### 7. Define a function that differentiates between continuous and discrete variables. Hint: A number of unique values might be useful. Store continuous data into a continuous variable and do the same for discrete and categorical.

# %%
continuous = []
discrete = []
for i in data.columns:
    if data[i].dtypes == 'int64':
        discrete.append(i)
    if data[i].dtypes == 'float64':
        continuous.append(i)
print(continuous, discrete)
# Out:
# ['customer_lifetime_value', 'total_claim_amount'] ['income', 'monthly_premium_auto', 'months_since_last_claim', 'months_since_policy_inception', 'number_of_open_complaints', 'number_of_policies']

# %% [markdown]
# ### 8. For the categorical data, check if there is some kind of text in a variable so we would need to clean it. Hint: Use the same method you used in step 7. Depending on the implementation, decide what to do with the variables you get.

# %%
categorical = []
for i in data.columns:
    if data[i].dtypes == 'object':
        categorical.append(i)
print(categorical)
# Out:
# ['customer', 'state', 'response', 'coverage', 'education', 'employmentstatus', 'gender', 'location_code', 'marital_status', 'policy_type', 'policy', 'renew_offer_type', 'sales_channel', 'vehicle_class', 'vehicle_size']

# %%
for col in data.select_dtypes('object'):
    print(data[col].value_counts(), '\n')
# Out:
# JW30054    1
# JG16015    1
# VQ82774    1
# QL77686    1
# NW62233    1
#           ..
# FQ24929    1
# CD26907    1
# XR36002    1
# JW44963    1
# VG58889    1
# Name: customer, Length: 9134, dtype: int64
#
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
#
# No     7826
# Yes    1308
# Name: response, dtype: int64
#
# Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
#
# Bachelor                2748
# College                 2681
# High School or Below    2622
# Master                   741
# Doctor                   342
# Name: education, dtype: int64
#
# Employed         5698
# Unemployed       2317
# Medical Leave     432
# Disabled          405
# Retired           282
# Name: employmentstatus, dtype: int64
#
# F    4658
# M    4476
# Name: gender, dtype: int64
#
# Suburban    5779
# Rural       1773
# Urban       1582
# Name: location_code, dtype: int64
#
# ...

# %%
data.set_index('customer')
# Out:
#                state  customer_lifetime_value response  coverage education  \
# customer
# BU79786   Washington              2763.519279       No     Basic  Bachelor
# QZ44356      Arizona              6979.535903       No  Extended  Bachelor
# AI49188       Nevada             12887.431650       No   Premium  Bachelor
# WW63253   California              7645.861827       No     Basic  Bachelor
# HB64268   Washington              2813.692575       No     Basic  Bachelor
# ...              ...                      ...      ...       ...       ...
# LA72316   California             23405.987980       No     Basic  Bachelor
# PK87824   California              3096.511217      Yes  Extended   College
# TD14365   California              8163.890428       No  Extended  Bachelor
# UP19263   California              7524.442436       No  Extended   College
# Y167826   California              2611.836866       No  Extended   College
#
# ...

# %% [markdown]
# ### 9. Get categorical features.

# %% [markdown]
# I didn't understand "get categorical features", wasn't what we did above?
# As featurres were already checked above I did cross tables to check data base reliability

# %% [markdown]
# I didn't understand "get categorical features", wasn't what we did above?

# %%
# checking how many different coverage by each gender
pd.crosstab(data['gender'], data['coverage'])
# Out:
# coverage  Basic  Extended  Premium
# gender
# F          2801      1432      425
# M          2767      1310      399

# %%
# checking how many different employment status by each education
pd.crosstab(data['employmentstatus'], data['education'])
# Out:
# education         Bachelor  College  Doctor  High School or Below  Master
# employmentstatus
# Disabled               121       98      22                   118      46
# Employed              1702     1664     249                  1528     555
# Medical Leave          126      145      17                   115      29
# Retired                 88      102       1                    72      19
# Unemployed             711      672      53                   789      92

# %%
# checking how many different policies type by each policy type
pd.crosstab(data['policy_type'], data['policy'])
# Out:
# policy          Corporate L1  Corporate L2  Corporate L3  Personal L1  \
# policy_type
# Corporate Auto           359           595          1014            0
# Personal Auto              0             0             0         1240
# Special Auto               0             0             0            0
#
# policy          Personal L2  Personal L3  Special L1  Special L2  Special L3
# policy_type
# Corporate Auto            0            0           0           0           0
# Personal Auto          2122         3426           0           0           0
# Special Auto              0            0          66         164         148

# %%
# checking how many different renew offer types by each sales channel
pd.crosstab(data['sales_channel'], data['renew_offer_type'])
# Out:
# renew_offer_type  Offer1  Offer2  Offer3  Offer4
# sales_channel
# Agent               1690     978     518     291
# Branch              1099     788     394     286
# Call Center          588     647     291     239
# Web                  375     513     229     208

# %%
# checking how many different sizes of each vehicle class
pd.crosstab(data['vehicle_class'], data['vehicle_size'])
# Out:
# vehicle_size   Large  Medsize  Small
# vehicle_class
# Four-Door Car    475     3237    909
# Luxury Car        16      106     41
# Luxury SUV        18      125     41
# SUV              167     1308    321
# Sports Car        49      366     69
# Two-Door Car     221     1282    383

# %%
state_count = data['state'].value_counts()
sns.set(style="darkgrid")
sns.barplot(state_count.index, state_count.values, alpha=0.9)
plt.title('Frequency Distribution of States')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Carrier', fontsize=12)
plt.show()
# Out:
# C:\Users\claud\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### 10. What should we do with the customer_id column?

# %% [markdown]
# As we only have unique values on that column is better to set as the index.
# This process makes the scripts run faster and eliminates the need of defining a type.
# The index setting was done on exercise 7.
